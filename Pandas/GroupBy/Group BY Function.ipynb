# %% [markdown]
# ### Import Dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
company=pd.read_csv("Fortune_1000.csv")
company.head()
# Out:
#        company  rank  rank_change   revenue   profit  num. of employees  \
# 0      Walmart     1          0.0  523964.0  14881.0            2200000
# 1       Amazon     2          3.0  280522.0  11588.0             798000
# 2  Exxon Mobil     3         -1.0  264938.0  14340.0              74900
# 3        Apple     4         -1.0  260174.0  55256.0             137000
# 4   CVS Health     5          3.0  256776.0   6634.0             290000
#
#         sector         city state newcomer ceo_founder ceo_woman profitable  \
# 0    Retailing  Bentonville    AR       no          no        no        yes
# 1    Retailing      Seattle    WA       no         yes        no        yes
# 2       Energy       Irving    TX       no          no        no        yes
# 3   Technology    Cupertino    CA       no          no        no        yes
# 4  Health Care   Woonsocket    RI       no          no       yes        yes
#
#   prev_rank                  CEO                        Website Ticker  \
# ...

# %% [markdown]
# ### Group_By Function:-

# %%
sectors=company.groupby('sector')

# %%
sectors

# %%
len(company)
# Out:
# 1000

# %%
len(sectors)
# Out:
# 21

# %%
sectors.size().sort_values(ascending=False)
# Out:
# sector
# Financials                       162
# Energy                           109
# Technology                       109
# Retailing                         75
# Health Care                       71
# Business Services                 52
# Industrials                       50
# Materials                         46
# Transportation                    38
# Food, Beverages & Tobacco         37
# Wholesalers                       35
# Engineering & Construction        30
# Hotels, Restaurants & Leisure     27
# Chemicals                         27
# Household Products                26
# Media                             25
# Motor Vehicles & Parts            22
# Aerospace & Defense               22
# Apparel                           16
# Telecommunications                11
# Food & Drug Stores                10
# dtype: int64

# %% [markdown]
# ### If we want to return the first itme of each group then we can used first function().

# %%
sectors.first().head()
# Out:
#                                    company  rank  rank_change   revenue  \
# sector
# Aerospace & Defense  Raytheon Technologies    39          7.0   77046.0
# Apparel                               Nike    85          5.0   39117.0
# Business Services                     Visa   137         16.0   22977.0
# Chemicals                              Dow    78          0.0   42951.0
# Energy                         Exxon Mobil     3         -1.0  264938.0
#
#                       profit  num. of employees           city state newcomer  \
# sector
# Aerospace & Defense   5537.0             243200        Waltham    MA       no
# Apparel               4029.0              76700      Beaverton    OR       no
# Business Services    12080.0              19500  San Francisco    CA       no
# Chemicals            -1359.0              36500        Midland    MI      yes
# Energy               14340.0              74900         Irving    TX       no
#
# ...

# %% [markdown]
# ### If we want to return the last itme of each group then we can used last function().

# %%
sectors.last().head()
# Out:
#                                        company  rank  rank_change  revenue  \
# sector
# Aerospace & Defense         Maxar Technologies   987          0.0   2033.0
# Apparel                        Deckers Outdoor   989          0.0   2020.4
# Business Services                Herc Holdings   997          0.0   1999.0
# Chemicals                            NewMarket   950          0.0   2190.3
# Energy               Liberty Oilfield Services  1000          0.0   1990.3
#
#                      profit  num. of employees            city state newcomer  \
# sector
# Aerospace & Defense   109.0               5800     Westminster    CO       no
# Apparel               264.3               3500          Goleta    CA       no
# Business Services      47.5               5100  Bonita Springs    FL       no
# Chemicals             254.3               2118        Richmond    VA       no
# Energy                 39.0               2571          Denver    CO       no
#
# ...

# %% [markdown]
# ### Groups() function is used to return the groups in form of dictionary.Where it contains the name of groups and index values of each element present in that groups.

# %%
sectors.groups
# Out:
# {'Aerospace & Defense': [38, 39, 56, 82, 95, 107, 225, 235, 249, 356, 405, 512, 647, 718, 750, 799, 802, 827, 904, 955, 976, 986], 'Apparel': [84, 232, 321, 435, 468, 484, 494, 528, 530, 688, 751, 773, 927, 941, 956, 988], 'Business Services': [136, 157, 181, 190, 199, 206, 210, 226, 302, 304, 307, 310, 339, 440, 450, 455, 461, 481, 520, 527, 540, 552, 560, 574, 598, 609, 614, 618, 651, 656, 661, 665, 668, 691, 708, 730, 741, 794, 830, 841, 846, 848, 856, 877, 890, 900, 905, 966, 974, 991, 992, 996], 'Chemicals': [77, 102, 151, 179, 208, 212, 342, 354, 355, 381, 390, 469, 480, 507, 510, 539, 577, 586, 682, 693, 716, 723, 725, 752, 804, 893, 949], 'Energy': [2, 14, 21, 26, 31, 58, 90, 92, 94, 97, 100, 122, 124, 126, 128, 141, 147, 152, 171, 183, 185, 188, 196, 203, 220, 241, 252, 255, 257, 258, 259, 269, 275, 292, 293, 309, 312, 316, 318, 323, 327, 328, 340, 341, 364, 370, 372, 373, 386, 407, 412, 415, 418, 422, 442, 448, 460, 464, 482, 487, 515, 523, 532, 533, 538, 580, 581, 584, 601
# ...

# %% [markdown]
# ### Get_group (This function return all the element in perticular group.)

# %%
sectors.get_group('Technology')
# Out:
#                    company  rank  rank_change   revenue   profit  \
# 3                    Apple     4         -1.0  260174.0  55256.0
# 10                Alphabet    11          4.0  161857.0  34343.0
# 20               Microsoft    21          5.0  125843.0  39240.0
# 33       Dell Technologies    34          0.0   92154.0   4616.0
# 37                     IBM    38          0.0   77147.0   9431.0
# ..                     ...   ...          ...       ...      ...
# 944  Cypress Semiconductor   945          0.0    2205.3     40.4
# 953               Fortinet   954          0.0    2156.2    326.5
# 963               EchoStar   964          0.0    2098.3    -62.9
# 967                 Bruker   968          0.0    2072.6    197.2
# 971                 Viasat   972          0.0    2068.3    -67.6
#
#      num. of employees      sector           city state newcomer ceo_founder  \
# 3               137000  Technology      Cupertino    CA       no          no
# ...

# %%
sectors.sum()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_16652\866269372.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sectors.sum()
#                                 rank  rank_change    revenue    profit  \
# sector
# Aerospace & Defense            10785        271.0   406385.3   26134.4
# Apparel                         9616         42.0   116856.9    9019.4
# Business Services              30795        328.0   338577.6   44526.9
# Chemicals                      13383       -438.0   253790.2   15806.1
# Energy                         52845       -636.0  1745779.1   80168.9
# Engineering & Construction     17140        101.0   215767.4    8460.9
# Financials                     76984        696.0  2748932.9  415521.9
# Food & Drug Stores              3983        -47.0   397831.6    8634.8
# ...

# %%
sectors.mean()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_16652\749096766.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sectors.mean()
#                                      rank  rank_change       revenue  \
# sector
# Aerospace & Defense            490.227273    12.318182  18472.059091
# Apparel                        601.000000     2.625000   7303.556250
# Business Services              592.211538     6.307692   6511.107692
# Chemicals                      495.666667   -16.222222   9399.637037
# Energy                         484.816514    -5.834862  16016.322018
# Engineering & Construction     571.333333     3.366667   7192.246667
# Financials                     475.209877     4.296296  16968.721605
# Food & Drug Stores             398.300000    -4.700000  39783.160000
# ...

# %%
sectors['revenue'].sum().sort_values(ascending=False)
# Out:
# sector
# Financials                       2748932.9
# Health Care                      2181964.6
# Retailing                        1885783.3
# Energy                           1745779.1
# Technology                       1677257.4
# Food, Beverages & Tobacco         553072.9
# Telecommunications                533713.0
# Industrials                       514162.2
# Transportation                    503125.7
# Motor Vehicles & Parts            443320.0
# Wholesalers                       420756.8
# Aerospace & Defense               406385.3
# Food & Drug Stores                397831.6
# Business Services                 338577.6
# Materials                         302809.5
# Chemicals                         253790.2
# Media                             234359.3
# Household Products                228037.3
# Engineering & Construction        215767.4
# Hotels, Restaurants & Leisure     200056.0
# Apparel                           116856.9
# Name: revenue, dtype: float64

# %%
sectors['revenue'].mean().sort_values(ascending=False)
# Out:
# sector
# Telecommunications               48519.363636
# Food & Drug Stores               39783.160000
# Health Care                      30731.895775
# Retailing                        25143.777333
# Motor Vehicles & Parts           20150.909091
# Aerospace & Defense              18472.059091
# Financials                       16968.721605
# Energy                           16016.322018
# Technology                       15387.682569
# Food, Beverages & Tobacco        14947.916216
# Transportation                   13240.150000
# Wholesalers                      12021.622857
# Industrials                      10283.244000
# Chemicals                         9399.637037
# Media                             9374.372000
# Household Products                8770.665385
# Hotels, Restaurants & Leisure     7409.481481
# Apparel                           7303.556250
# Engineering & Construction        7192.246667
# Materials                         6582.815217
# ...

# %%
cricket=pd.read_csv("ipl.csv").head()
cricket.head()
# Out:
#    id  season        city        date                  team1  \
# 0   1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1   2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2   3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3   4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4   5    2008     Kolkata  2008-04-20        Deccan Chargers
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
# 2             Delhi Daredevils             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4        Kolkata Knight Riders              Deccan Chargers           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0        Kolkata Knight Riders          140
# ...

# %% [markdown]
# ### deleivery dataset

# %%
crick_df=pd.read_csv("deliveries.csv")
crick_df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
name=crick_df.groupby('batsman')

# %%
print(type(name))
# Out:
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>

# %%
name.size()
# Out:
# batsman
# A Ashish Reddy     196
# A Chandila           7
# A Chopra            75
# A Choudhary         20
# A Flintoff          57
#                   ...
# YV Takawale        183
# Yashpal Singh       67
# Younis Khan          7
# Yuvraj Singh      2050
# Z Khan             141
# Length: 461, dtype: int64

# %%
name.get_group('V Kohli')
# Out:
#         match_id  inning                 batting_team         bowling_team  \
# 2590          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2591          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2593          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2594          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2597          12       1  Royal Challengers Bangalore       Mumbai Indians
# ...          ...     ...                          ...                  ...
# 150410       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150413       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150414       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150415       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150416       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
#
# ...

# %%
name.sum()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_16652\198126005.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   name.sum()
#                 match_id  inning   over  ball  is_super_over  wide_runs  \
# batsman
# A Ashish Reddy     90024     277   3312   720              0          3
# A Chandila          2815       7    132    23              0          0
# A Chopra            7602      78    467   273              0          4
# A Choudhary          614      28    371    71              0          0
# A Flintoff          6908     100    670   203              0          4
# ...                  ...     ...    ...   ...            ...        ...
# YV Takawale        54862     305   1017   695              0          5
# Yashpal Singh       9918     113    578   250              0          1
# ...

# %% [markdown]
# ### We need to find out top 5 batsmans name in 10 years.

# %%
name['batsman_runs'].sum().sort_values(ascending=False).head()
# Out:
# batsman
# SK Raina     4548
# V Kohli      4423
# RG Sharma    4207
# G Gambhir    4132
# DA Warner    4014
# Name: batsman_runs, dtype: int64

# %% [markdown]
# ### We need to find out top 5 batsmans name who hits more sixes in 10 years.

# %%
mask=crick_df['batsman_runs']==6
new_delivery=crick_df[mask]

# %%
mask
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 150455    False
# 150456    False
# 150457    False
# 150458    False
# 150459    False
# Name: batsman_runs, Length: 150460, dtype: bool

# %%
crick_df[mask].head()
# Out:
#     match_id  inning         batting_team                 bowling_team  over  \
# 10         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 47         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     8
# 75         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    13
# 89         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    15
# 91         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    15
#
#     ball       batsman   non_striker       bowler  is_super_over  ...  \
# 10     4     DA Warner      S Dhawan  A Choudhary              0  ...
# 47     4  MC Henriques      S Dhawan      TM Head              0  ...
# 75     2  Yuvraj Singh  MC Henriques  A Choudhary              0  ...
# 89     3  Yuvraj Singh  MC Henriques    S Aravind              0  ...
# 91     5  MC Henriques  Yuvraj Singh    S Aravind              0  ...
#
#     bye_runs  legbye_runs  noball_runs  penalty_runs  batsman_runs  \
# ...

# %%
new_delivery.head()
# Out:
#     match_id  inning         batting_team                 bowling_team  over  \
# 10         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 47         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     8
# 75         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    13
# 89         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    15
# 91         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    15
#
#     ball       batsman   non_striker       bowler  is_super_over  ...  \
# 10     4     DA Warner      S Dhawan  A Choudhary              0  ...
# 47     4  MC Henriques      S Dhawan      TM Head              0  ...
# 75     2  Yuvraj Singh  MC Henriques  A Choudhary              0  ...
# 89     3  Yuvraj Singh  MC Henriques    S Aravind              0  ...
# 91     5  MC Henriques  Yuvraj Singh    S Aravind              0  ...
#
#     bye_runs  legbye_runs  noball_runs  penalty_runs  batsman_runs  \
# ...

# %% [markdown]
# ### Calculate the total fours in ipl till now.

# %%
new_delivery.shape[0]
# Out:
# 6523

# %%
new_delivery.groupby('batsman')['batsman_runs'].count().sort_values(ascending=False).head()
# Out:
# batsman
# CH Gayle     266
# SK Raina     174
# RG Sharma    173
# V Kohli      160
# DA Warner    160
# Name: batsman_runs, dtype: int64

# %% [markdown]
# ### We need to find out top 5 batsmans name who hits more fours in 10 years.

# %%
mask=crick_df['batsman_runs']==4
four_runs=crick_df[mask]

# %%
four_runs.head()
# Out:
#     match_id  inning         batting_team                 bowling_team  over  \
# 2          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 8          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 13         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 30         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     5
# 32         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     6
#
#     ball       batsman   non_striker       bowler  is_super_over  ...  \
# 2      3     DA Warner      S Dhawan     TS Mills              0  ...
# 8      2     DA Warner      S Dhawan  A Choudhary              0  ...
# 13     7  MC Henriques      S Dhawan  A Choudhary              0  ...
# 30     5  MC Henriques      S Dhawan    S Aravind              0  ...
# 32     1      S Dhawan  MC Henriques    SR Watson              0  ...
#
#     bye_runs  legbye_runs  noball_runs  penalty_runs  batsman_runs  \
# ...

# %%
four_runs.groupby('batsman')['batsman_runs'].count().sort_values(ascending=False).head()
# Out:
# batsman
# G Gambhir    484
# SK Raina     402
# DA Warner    401
# S Dhawan     401
# V Kohli      384
# Name: batsman_runs, dtype: int64

# %% [markdown]
# ### Find out top 3 teams in last 10 years against where Virat kohli do lots of runs.

# %%
vk=crick_df[crick_df['batsman']=='V Kohli']
vk.head()
# Out:
#       match_id  inning                 batting_team    bowling_team  over  \
# 2590        12       1  Royal Challengers Bangalore  Mumbai Indians     1
# 2591        12       1  Royal Challengers Bangalore  Mumbai Indians     1
# 2593        12       1  Royal Challengers Bangalore  Mumbai Indians     1
# 2594        12       1  Royal Challengers Bangalore  Mumbai Indians     1
# 2597        12       1  Royal Challengers Bangalore  Mumbai Indians     2
#
#       ball  batsman non_striker           bowler  is_super_over  ...  \
# 2590     2  V Kohli    CH Gayle       TG Southee              0  ...
# 2591     3  V Kohli    CH Gayle       TG Southee              0  ...
# 2593     5  V Kohli    CH Gayle       TG Southee              0  ...
# 2594     6  V Kohli    CH Gayle       TG Southee              0  ...
# 2597     1  V Kohli    CH Gayle  Harbhajan Singh              0  ...
#
#       bye_runs  legbye_runs  noball_runs  penalty_runs  batsman_runs  \
# ...

# %%
vk.groupby('bowling_team')['batsman_runs'].sum().sort_values(ascending=False).head().reset_index()['batsman_runs']
# Out:
# 0    706
# 1    661
# 2    483
# 3    447
# 4    439
# Name: batsman_runs, dtype: int64

# %%
def most_run(batsman_name):
    vk=crick_df[crick_df['batsman']==batsman_name]
    return vk.groupby('bowling_team')['batsman_runs'].sum().sort_values(ascending=False).head(1).index[0]

# %%
most_run('MS Dhoni')
# Out:
# 'Royal Challengers Bangalore'

# %%
crick_df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %% [markdown]
# #### Find the Virat kohli runs agains each Team.

# %%
player=crick_df[crick_df['batsman']=='V Kohli']
#print(name.groupby('bowling_team')['batsman_runs'].sum())
player.groupby('bowling_team')['batsman_runs'].sum().reset_index()
# Out:
#                bowling_team  batsman_runs
# 0       Chennai Super Kings           706
# 1           Deccan Chargers           306
# 2          Delhi Daredevils           661
# 3             Gujarat Lions           283
# 4           Kings XI Punjab           483
# 5      Kochi Tuskers Kerala            50
# 6     Kolkata Knight Riders           391
# 7            Mumbai Indians           447
# 8             Pune Warriors           128
# 9          Rajasthan Royals           258
# 10   Rising Pune Supergiant            83
# 11  Rising Pune Supergiants           188
# 12      Sunrisers Hyderabad           439

# %%
player
# Out:
#         match_id  inning                 batting_team         bowling_team  \
# 2590          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2591          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2593          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2594          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2597          12       1  Royal Challengers Bangalore       Mumbai Indians
# ...          ...     ...                          ...                  ...
# 150410       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150413       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150414       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150415       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150416       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
#
# ...

# %% [markdown]
# #### total number of ball played by Player against each team.

# %%
name=crick_df[crick_df['batsman']=='V Kohli']
player['ball_played']=name.groupby('bowling_team')['ball'].count().reset_index()['ball']
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_16652\1051099824.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   player['ball_played']=name.groupby('bowling_team')['ball'].count().reset_index()['ball']

# %%
player.drop(labels='Ball_played',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 player.drop(labels='Ball_played',axis=1,inplace=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
# ...

# %%
player

# %%
player['Strike_rate']=player['batsman_runs']/player['ball_played']*100

# %%
player

# %%
vk_four=crick_df[(crick_df['batsman_runs']==4) & (crick_df['batsman']=='V Kohli')]
#print(vk_four.groupby('bowling_team')['batsman_runs'].count())
player['player_four']=vk_four.groupby('bowling_team')['batsman_runs'].count().sort_values(ascending=False).reset_index()['batsman_runs']
print(player)

# %%
vk_four=crick_df[(crick_df['batsman_runs']==6) & (crick_df['batsman']=='CH Gayle')]
player['player_sixes']=vk_four.groupby('bowling_team')['batsman_runs'].count().sort_values(ascending=False).reset_index()['batsman_runs']
player

# %% [markdown]
# ### Batsman Record.

# %%
def batsman_record(batsman):
    print("Total number of runs against each team")
    name=crick_df[crick_df['batsman']==batsman]
    player=name.groupby('bowling_team')['batsman_runs'].sum().sort_values(ascending=False).reset_index()
    print("Name of Player =",batsman)
    b_four=crick_df[(crick_df['batsman_runs']==4) & (crick_df['batsman']==batsman)]
    player['No_Of_fours']=b_four.groupby('bowling_team')['batsman_runs'].count().sort_values(ascending=False).reset_index()['batsman_runs']
    b_six=crick_df[(crick_df['batsman_runs']==6) & (crick_df['batsman']==batsman)]
    player['NO_Of_sixes']=b_six.groupby('bowling_team')['batsman_runs'].count().sort_values(ascending=False).reset_index()['batsman_runs']
    name=crick_df[crick_df['batsman']==batsman]
    player['ball_played']=name.groupby('bowling_team')['ball'].count().reset_index()['ball']
    player['Strike_rate']=player['batsman_runs']/player['ball_played']*100
    return player

# %%
batsman_record('DA Warner')

# %%
crick_df['batsman'].unique()

# %% [markdown]
# ### Titanic Dataset..

# %%
titanic_df=pd.read_csv("titanic.csv")
titanic_df.head()

# %% [markdown]
# #### Q-1: Using groupby make groups using the "Pclass" column and find out the average age and total number of missing values in the "Age" column for every group.

# %%
print("Avg Age og passengers based on Pclass")
Avg_age=titanic_df.groupby('Pclass')['Age'].mean()
print(Avg_age)

# %%
print("Total number of missing values in Age based on Pclass")
Age_val=titanic_df[titanic_df['Age'].isnull()]
print(Age_val)
result=Age_val.groupby('Pclass')['Age'].count()

# %% [markdown]
# #### Using groupby make groups using the "Pclass" column and fill every group's "Embarked" column's missing values with the mode value of that group. After that, print every group's "Embarked" column's value counts in ascending order.

# %%
x=titanic_df['Embarked'].mode()

# %%
titanic_df['Embarked'].fillna(titanic_df['Embarked'].mode(),inplace=True)

# %%
titanic_df.groupby(['Pclass','Embarked'])['Embarked'].count()

# %% [markdown]
# #### Q-3: Make groups based on "Embarked" column. And for each of this embarked group, make another group based on "Pclass" and find out the average fare (round off up to 2 decimal places) for each "Pclass" for each group of "Embarked".

# %%
round(titanic_df.groupby(['Embarked','Pclass'])['Fare'].mean(),2)

# %% [markdown]
# ### Fifa Worldcup Dataset.

# %%
fifa_df=pd.read_csv("Fifa Worldcup 2022.csv")
print(fifa_df.head())

# %%
fifa_df.columns

# %%
team=fifa_df.groupby('Team')

# %%
type(team)

# %%
def normalization(group,used_col):
    for col in used_col:
        std=group[col].std()
        mean=group[col].mean()
        group[f"{col}_n_norm"]=(group[col]-mean)/std
    return group

# %%
used_col=['Passes','Passes Completed','Attempted Line Breaks','Completed Line Breaks']

# %%
groups=fifa_df.groupby('Team')
groups.apply(normalization,used_col).groupby('Team')
groups.agg(
           {
               'Passes':['min','max'],
               'Yellow Cards':['min','max','mean'],
               'Attempted Line Breaks':['min','max','std'],
               'Possession (%)':['mean']  
           }).head()

# %%
c_df=pd.read_csv("deliveries.csv")
print(c_df.head())
print(c_df.shape)

# %%
run=c_df[c_df['inning']==2]
#print(run.head())
print("Successful run chase by team")
print()
run_chase=run.groupby(['batting_team','match_id','bowling_team'])['total_runs'].sum().sort_values(ascending=False).head(30).reset_index().drop_duplicates(subset='batting_team',keep='first')
print(type(run_chase))
run_chase.drop(labels='match_id',axis=1,inplace=True)
run_chase

# %%
run.groupby(['match_id','batsman'])['batsman_runs'].sum().sort_values(ascending=False).head()

# %%
print("Most successful batting pair in IPL")
c_df.groupby(['batting_team','batsman','non_striker'])['total_runs'].sum().sort_values(ascending=False).head(30).reset_index().drop_duplicates(subset='batting_team',keep='first')

# %%
c_df['dismissal_kind'].unique()

# %%
print("Successful bowler against any batsman")
c_df.groupby(['batsman','bowler'])['dismissal_kind'].count().sort_values(ascending=False).head(10).reset_index().drop_duplicates(subset='batsman',keep='first')

# %% [markdown]
# #### Q-5: Find batsman in below category-
# Highest score while chasing
# Best Strike rate while chasing and have faced 100+ balls

# %%
c_df.head()

# %%
run=c_df[(c_df['inning']==2)]
#print(run)
run_chase=run.groupby(['batsman','match_id','bowling_team'])['batsman_runs'].sum().sort_values(ascending=False).head(20).reset_index().drop_duplicates(subset='batsman',keep='first')
#run_chase=run.groupby(['batsman','match_id','bowling_team'])['ball'].count().sort_values(ascending=False).head(20)
four=run[run['batsman_runs']==4]
run_chase["No_Of_Four"]=four.groupby(['batsman','bowling_team','match_id'])['batsman_runs'].count().sort_values(ascending=False).reset_index()['batsman_runs']
sixes=run[run['batsman_runs']==6]
run_chase["No_Of_Sixes"]=sixes.groupby(['batsman','bowling_team','match_id'])['batsman_runs'].count().sort_values(ascending=False).reset_index()['batsman_runs']
ball_play=run['ball']
print(type(run_chase))
#run_chase.drop(labels='match_id',axis=1,inplace=True)
run_chase

# %%
name=c_df[c_df['batsman']=='CH Gayle']

# %%
name.groupby(['match_id','bowling_team'])['batsman_runs'].sum().sort_values(ascending=False).head(10)

# %%
name=run[(run['batsman_runs']==6)]
name.head()

# %%
sixes.head(1)

# %%
run

# %%
balls

# %%
run_chase['ball_played']=run.groupby(['batsman','bowling_team','match_id'])['ball'].count().sort_values(ascending=False).head(30).reset_index()['ball']

# %%
run_chase

# %%
c_df.head()
